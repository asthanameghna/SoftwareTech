# %%
import pandas

datadf = pandas.read_csv('dataset.csv',  sep=',', names=['itemid', 'timestamp', 'transactionid', 'productid'])
datadf
# Out:
#         itemid  timestamp  transactionid  productid
# 0            1    1000029              2         12
# 1            2    1000031              2          6
# 2            3    1000034              2         91
# 3            4    1000037              2         60
# 4            5    1000038              2         91
# 5            5    1000075              3         37
# 6            6    1000076              3         28
# 7            7    1000078              3         68
# 8            8    1000080              3         27
# 9            9    1000081              3         47
# 10          10    1000084              3         27
# 11          10    1000114              4         58
# 12          11    1000116              4         30
# 13          12    1000118              4         29
# 14          13    1000120              4         89
# 15          13    1000157              5         94
# 16          13    1000184              6         53
# ...

# %%
import numpy

df = pandas.DataFrame(datadf['transactionid'], columns = ['transactionid'])
df['productid'] = datadf['productid']
data = df.values
grouped = df.groupby('transactionid')

itemIndex = [grouped['productid'].groups[i].values for i in range(2,len(grouped)+2)]

# %%
items = []
for j in range(len(grouped)): 
    a = [df['productid'][i]for i in range(itemIndex[j][0], itemIndex[j][0]+len(itemIndex[j]))]
    items.append(a)
items
# Out:
# [[12, 6, 91, 60, 91],
#  [37, 28, 68, 27, 47, 27],
#  [58, 30, 29, 89],
#  [94],
#  [53, 17],
#  [18, 93, 18, 93, 87],
#  [56, 80, 51, 55, 51, 69],
#  [55, 87, 84, 87, 41, 5, 41],
#  [38, 99, 92, 27],
#  [18, 18, 19],
#  [33, 27],
#  [70, 19, 88],
#  [87],
#  [53, 17, 53],
#  [96, 40, 96, 91],
#  [87, 42, 41, 87, 15],
#  [60, 8, 60, 15, 72],
#  [12, 43, 99, 16],
#  [78, 80],
#  [98, 18, 93, 23, 82],
#  [63, 60, 91, 85, 22],
#  [32, 40, 32],
#  [30, 29, 89, 29, 30],
#  [64, 50],
#  [65, 29, 30, 91, 13, 63, 38],
#  [60, 27, 47, 52],
#  [88, 43, 99, 37, 99, 43, 99],
#  [80, 70, 40],
#  [90, 38, 92, 26, 92],
#  [55],
#  [18, 98, 2, 14, 58, 25],
#  [41, 50, 41, 50],
#  [14, 58, 25, 20],
#  [40, 32, 40, 12, 6],
#  [35],
#  [46, 57, 74, 59, 31],
#  [95, 34],
#  [77],
#  [96, 30, 47],
#  [1, 47, 69, 29, 30, 43, 30],
#  [80, 70, 19, 94],
#  [44, 5],
#  [89, 76, 89, 76],
#  [43, 12, 43],
#  [73, 9, 54, 98, 54, 4],
#  [26, 73],
#  [82, 23],
#  [50, 98, 54, 98, 50, 72],
# ...

# %%
items[:10]
# Out:
# [[12, 6, 91, 60, 91],
#  [37, 28, 68, 27, 47, 27],
#  [58, 30, 29, 89],
#  [94],
#  [53, 17],
#  [18, 93, 18, 93, 87],
#  [56, 80, 51, 55, 51, 69],
#  [55, 87, 84, 87, 41, 5, 41],
#  [38, 99, 92, 27],
#  [18, 18, 19]]

# %%
from numpy import *

# %%
def loadDataSet():
    return items

# %%
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1)

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
dataSet = loadDataSet()
dataSet
# Out:
# [[12, 6, 91, 60, 91],
#  [37, 28, 68, 27, 47, 27],
#  [58, 30, 29, 89],
#  [94],
#  [53, 17],
#  [18, 93, 18, 93, 87],
#  [56, 80, 51, 55, 51, 69],
#  [55, 87, 84, 87, 41, 5, 41],
#  [38, 99, 92, 27],
#  [18, 18, 19],
#  [33, 27],
#  [70, 19, 88],
#  [87],
#  [53, 17, 53],
#  [96, 40, 96, 91],
#  [87, 42, 41, 87, 15],
#  [60, 8, 60, 15, 72],
#  [12, 43, 99, 16],
#  [78, 80],
#  [98, 18, 93, 23, 82],
#  [63, 60, 91, 85, 22],
#  [32, 40, 32],
#  [30, 29, 89, 29, 30],
#  [64, 50],
#  [65, 29, 30, 91, 13, 63, 38],
#  [60, 27, 47, 52],
#  [88, 43, 99, 37, 99, 43, 99],
#  [80, 70, 40],
#  [90, 38, 92, 26, 92],
#  [55],
#  [18, 98, 2, 14, 58, 25],
#  [41, 50, 41, 50],
#  [14, 58, 25, 20],
#  [40, 32, 40, 12, 6],
#  [35],
#  [46, 57, 74, 59, 31],
#  [95, 34],
#  [77],
#  [96, 30, 47],
#  [1, 47, 69, 29, 30, 43, 30],
#  [80, 70, 19, 94],
#  [44, 5],
#  [89, 76, 89, 76],
#  [43, 12, 43],
#  [73, 9, 54, 98, 54, 4],
#  [26, 73],
#  [82, 23],
#  [50, 98, 54, 98, 50, 72],
# ...

# %%
C1 = createC1(dataSet)

# %%
C1
# Out:
# [frozenset({1}),
#  frozenset({2}),
#  frozenset({3}),
#  frozenset({4}),
#  frozenset({5}),
#  frozenset({6}),
#  frozenset({7}),
#  frozenset({8}),
#  frozenset({9}),
#  frozenset({10}),
#  frozenset({11}),
#  frozenset({12}),
#  frozenset({13}),
#  frozenset({14}),
#  frozenset({15}),
#  frozenset({16}),
#  frozenset({17}),
#  frozenset({18}),
#  frozenset({19}),
#  frozenset({20}),
#  frozenset({21}),
#  frozenset({22}),
#  frozenset({23}),
#  frozenset({24}),
#  frozenset({25}),
#  frozenset({26}),
#  frozenset({27}),
#  frozenset({28}),
#  frozenset({29}),
#  frozenset({30}),
#  frozenset({31}),
#  frozenset({32}),
#  frozenset({33}),
#  frozenset({34}),
#  frozenset({35}),
#  frozenset({36}),
#  frozenset({37}),
#  frozenset({38}),
#  frozenset({39}),
#  frozenset({40}),
#  frozenset({41}),
#  frozenset({42}),
#  frozenset({43}),
#  frozenset({44}),
#  frozenset({45}),
#  frozenset({46}),
#  frozenset({47}),
#  frozenset({48}),
#  frozenset({49}),
#  frozenset({50}),
# ...

# %%
#D is a dataset in the setform.

D = list(map(set,dataSet))

# %%
D
# Out:
# [{6, 12, 60, 91},
#  {27, 28, 37, 47, 68},
#  {29, 30, 58, 89},
#  {94},
#  {17, 53},
#  {18, 87, 93},
#  {51, 55, 56, 69, 80},
#  {5, 41, 55, 84, 87},
#  {27, 38, 92, 99},
#  {18, 19},
#  {27, 33},
#  {19, 70, 88},
#  {87},
#  {17, 53},
#  {40, 91, 96},
#  {15, 41, 42, 87},
#  {8, 15, 60, 72},
#  {12, 16, 43, 99},
#  {78, 80},
#  {18, 23, 82, 93, 98},
#  {22, 60, 63, 85, 91},
#  {32, 40},
#  {29, 30, 89},
#  {50, 64},
#  {13, 29, 30, 38, 63, 65, 91},
#  {27, 47, 52, 60},
#  {37, 43, 88, 99},
#  {40, 70, 80},
#  {26, 38, 90, 92},
#  {55},
#  {2, 14, 18, 25, 58, 98},
#  {41, 50},
#  {14, 20, 25, 58},
#  {6, 12, 32, 40},
#  {35},
#  {31, 46, 57, 59, 74},
#  {34, 95},
#  {77},
#  {30, 47, 96},
#  {1, 29, 30, 43, 47, 69},
#  {19, 70, 80, 94},
#  {5, 44},
#  {76, 89},
#  {12, 43},
#  {4, 9, 54, 73, 98},
#  {26, 73},
#  {23, 82},
#  {50, 54, 72, 98},
#  {9, 22, 32, 40, 69, 96},
#  {22, 27, 68, 85, 89},
#  {35, 79},
#  {1, 47, 60, 66},
#  {29, 69},
#  {22, 45, 67, 85, 90, 100},
# ...

# %%
L1,suppDat0 = scanD(D,C1,0.5)
L1
# Out:
# []

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori(dataSet, minSupport = 0.01):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
L,suppData = apriori(dataSet)

# %%
L
# Out:
# [[frozenset({86}),
#   frozenset({75}),
#   frozenset({36}),
#   frozenset({7}),
#   frozenset({11}),
#   frozenset({81}),
#   frozenset({71}),
#   frozenset({3}),
#   frozenset({49}),
#   frozenset({61}),
#   frozenset({48}),
#   frozenset({97}),
#   frozenset({39}),
#   frozenset({10}),
#   frozenset({21}),
#   frozenset({83}),
#   frozenset({62}),
#   frozenset({24}),
#   frozenset({100}),
#   frozenset({67}),
#   frozenset({45}),
#   frozenset({66}),
#   frozenset({79}),
#   frozenset({73}),
#   frozenset({54}),
#   frozenset({9}),
#   frozenset({4}),
#   frozenset({76}),
#   frozenset({44}),
#   frozenset({1}),
#   frozenset({77}),
#   frozenset({95}),
#   frozenset({34}),
#   frozenset({74}),
#   frozenset({59}),
#   frozenset({57}),
#   frozenset({46}),
#   frozenset({31}),
#   frozenset({35}),
#   frozenset({20}),
#   frozenset({25}),
#   frozenset({14}),
#   frozenset({2}),
#   frozenset({90}),
#   frozenset({26}),
#   frozenset({52}),
#   frozenset({65}),
# ...

# %%
print('Most Frequent Items:\n')

freq_items = []
for l in L[0]:
    freq_items.append([next(iter(l)) for _ in range(1)][0]) 
    
print(freq_items)
# Out:
# Most Frequent Items:
#
# [86, 75, 36, 7, 11, 81, 71, 3, 49, 61, 48, 97, 39, 10, 21, 83, 62, 24, 100, 67, 45, 66, 79, 73, 54, 9, 4, 76, 44, 1, 77, 95, 34, 74, 59, 57, 46, 31, 35, 20, 25, 14, 2, 90, 26, 52, 65, 13, 64, 50, 32, 85, 63, 22, 98, 82, 23, 78, 43, 16, 72, 8, 42, 15, 96, 40, 88, 70, 33, 19, 99, 92, 38, 84, 41, 5, 80, 69, 56, 55, 51, 93, 87, 18, 53, 17, 94, 89, 58, 30, 29, 68, 47, 37, 28, 27, 91, 60, 12, 6]

# %%
L[1]
# Out:
# [frozenset({5, 49}),
#  frozenset({80, 100}),
#  frozenset({76, 82}),
#  frozenset({15, 75}),
#  frozenset({5, 28}),
#  frozenset({32, 88}),
#  frozenset({35, 91}),
#  frozenset({48, 72}),
#  frozenset({78, 86}),
#  frozenset({16, 71}),
#  frozenset({5, 52}),
#  frozenset({14, 62}),
#  frozenset({71, 100}),
#  frozenset({6, 21}),
#  frozenset({23, 83}),
#  frozenset({76, 92}),
#  frozenset({14, 74}),
#  frozenset({56, 71}),
#  frozenset({31, 83}),
#  frozenset({22, 56}),
#  frozenset({7, 66}),
#  frozenset({19, 22}),
#  frozenset({20, 22}),
#  frozenset({22, 75}),
#  frozenset({36, 94}),
#  frozenset({7, 98}),
#  frozenset({1, 4}),
#  frozenset({6, 11}),
#  frozenset({5, 77}),
#  frozenset({11, 80}),
#  frozenset({73, 93}),
#  frozenset({32, 81}),
#  frozenset({97, 100}),
#  frozenset({15, 88}),
#  frozenset({9, 58}),
#  frozenset({78, 97}),
#  frozenset({8, 79}),
#  frozenset({32, 82}),
#  frozenset({3, 57}),
#  frozenset({20, 37}),
#  frozenset({49, 73}),
#  frozenset({42, 84}),
# ...

# %%
L[2]
# Out:
# []

# %%
aprioriGen(L[0],2)
# Out:
# [frozenset({75, 86}),
#  frozenset({36, 86}),
#  frozenset({7, 86}),
#  frozenset({11, 86}),
#  frozenset({81, 86}),
#  frozenset({71, 86}),
#  frozenset({3, 86}),
#  frozenset({49, 86}),
#  frozenset({61, 86}),
#  frozenset({48, 86}),
#  frozenset({86, 97}),
#  frozenset({39, 86}),
#  frozenset({10, 86}),
#  frozenset({21, 86}),
#  frozenset({83, 86}),
#  frozenset({62, 86}),
#  frozenset({24, 86}),
#  frozenset({86, 100}),
#  frozenset({67, 86}),
#  frozenset({45, 86}),
#  frozenset({66, 86}),
#  frozenset({79, 86}),
#  frozenset({73, 86}),
#  frozenset({54, 86}),
#  frozenset({9, 86}),
#  frozenset({4, 86}),
#  frozenset({76, 86}),
#  frozenset({44, 86}),
#  frozenset({1, 86}),
#  frozenset({77, 86}),
#  frozenset({86, 95}),
#  frozenset({34, 86}),
#  frozenset({74, 86}),
#  frozenset({59, 86}),
#  frozenset({57, 86}),
#  frozenset({46, 86}),
#  frozenset({31, 86}),
#  frozenset({35, 86}),
#  frozenset({20, 86}),
#  frozenset({25, 86}),
#  frozenset({14, 86}),
# ...

# %%
def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
L,suppData= apriori(dataSet,minSupport=0.01)

# %%
rules= generateRules(L,suppData, minConf=0.7)
# Out:
# frozenset({36}) --> frozenset({94}) conf: 0.7447013487475915
# frozenset({81}) --> frozenset({32}) conf: 0.9295093296475466
# frozenset({95}) --> frozenset({34}) conf: 0.8040023543260741
# frozenset({53}) --> frozenset({17}) conf: 0.9469259064634789
# frozenset({17}) --> frozenset({53}) conf: 0.9504219409282701

# %%
print('Final result\n')
print('Rules:')
for r in rules:
    prod1=[next(iter(r[0])) for _ in range(1)]
    prod2=[next(iter(r[1])) for _ in range(1)]
    conf=r[2]
    print('Product ',prod1[0],' --> Product ',prod2[0], ' with conf: ', round(conf,3))
# Out:
# Final result
#
# Rules:
# Product  36  --> Product  94  with conf:  0.745
# Product  81  --> Product  32  with conf:  0.93
# Product  95  --> Product  34  with conf:  0.804
# Product  53  --> Product  17  with conf:  0.947
# Product  17  --> Product  53  with conf:  0.95
